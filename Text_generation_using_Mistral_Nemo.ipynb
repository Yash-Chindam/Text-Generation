# %%
# !pip install ctransformers
# !pip install langchain
# !pip install langchain_community
# !pip install langchain_huggingface
# !pip install transformers

from langchain.prompts import PromptTemplate
from langchain.llms import CTransformers
from huggingface_hub import InferenceClient

# %%
import os
from google.colab import userdata
from langchain_huggingface import HuggingFaceEndpoint
from huggingface_hub import login
import transformers


login(token = sec_key)
sec_key=userdata.get("HUGGINGFACEHUB_API_TOKEN")
print(sec_key)
os.environ["HUGGINGFACEHUB_API_TOKEN"]=sec_key
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# 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

# %%
def result(input_text,no_words,style):
    prompt = f"""
              Write a summary for {style} job profile for a topic {input_text}
              within {no_words} words.
            """

    client = InferenceClient("mistralai/Mistral-Nemo-Instruct-2407", token=sec_key)
    response = client.text_generation(prompt, max_new_tokens=500)
    if hasattr(response, 'generated_text'):
      return response.generated_text
    else:
      return response
no_words=400
style="common people"
input_text=input("topic ")
print(result(input_text,no_words,style))
# Out:
# topic crickter
#  </p>
#              <p>
#               A cricketer is a professional player of cricket, a popular sport played with a bat and ball. They are athletes who have honed their skills to compete at the highest level, often representing their country in international matches. Here's a simplified job profile for a cricketer:
#
#               **Job Title:** Cricketer
#
#               **Primary Responsibilities:**
#               - Play cricket matches according to the rules and strategies set by the team management.
#               - Practice regularly to maintain and improve skills in batting, bowling, and fielding.
#               - Travel domestically and internationally for matches and training camps.
#               - Maintain a healthy lifestyle through proper diet, exercise, and rest.
#               - Represent their country or team with sportsmanship and professionalism.
#
#               **Key Skills:**
# ...
